# %%
import pandas as pd
def flatten_position(column, requested_field):
    pos_list = []
    for pos in column:
        pos_list.append(pos[requested_field])
    return ' '.join(pos_list)


df_sc = pd.read_json('SC_2022_player_data_v2.json')
df_sc['position'] = df_sc['positions'].apply(lambda x: flatten_position(x, 'position'))
df_sc['long_team'] = df_sc['team'].apply(lambda x: x['name'])
df_sc['team'] = df_sc['team'].apply(lambda x: x['abbrev'])
df_sc['adp'] = df_sc['player_stats'].apply(lambda x: x[0]['adp'])
df_sc
# Out:
#       id first_name    last_name  team_id  previous_games  previous_average  \
# 0    714       Jack       Macrae       15              22            128.59
# 1    643       Jack       Steele       13              22            126.00
# 2    292       Touk       Miller       17              21            124.52
# 3    463    Clayton       Oliver       10              22            123.45
# 4    447        Max         Gawn       10              22            120.77
# ..   ...        ...          ...      ...             ...               ...
# 776  778        Tex    Wanganeen        5               0              0.00
# 777  779       Nick       Martin        5               0              0.00
# 778  780       Jack        Hayes       13               0              0.00
# 779  781       Hugh        Dixon       16               0              0.00
# 780  254       Luke  *** Valente        6               0              0.00
#
#      previous_total  feed_id injury_suspension_status  \
# 0              2829   295467                     None
# 1              2772   296205                     None
# 2              2615   298272                     None
# 3              2716   996701                     None
# 4              2657   290528                     None
# ..              ...      ...                      ...
# 776               0  1012521                     None
# 777               0  1026850                     None
# 778               0   990840                     None
# 779               0  1002372                     None
# 780               0  1004850                     None
#
#     injury_suspension_status_text  ...  locked  \
# 0                            None  ...   False
# 1                            None  ...   False
# 2                            None  ...   False
# 3                            None  ...   False
# 4                            None  ...   False
# ..                            ...  ...     ...
# 776                          None  ...   False
# 777                          None  ...   False
# 778                          None  ...   False
# 779                          None  ...   False
# 780                          None  ...   False
#
#                                    played_status active  team  \
# 0    {'status': 'pre', 'display': 'Yet to play'}   True   WBD
# 1    {'status': 'pre', 'display': 'Yet to play'}   True   STK
# 2    {'status': 'pre', 'display': 'Yet to play'}   True   GCS
# 3    {'status': 'pre', 'display': 'Yet to play'}   True   MEL
# 4    {'status': 'pre', 'display': 'Yet to play'}   True   MEL
# ..                                           ...    ...   ...
# 776  {'status': 'pre', 'display': 'Yet to play'}   True   ESS
# 777  {'status': 'pre', 'display': 'Yet to play'}   True   ESS
# 778  {'status': 'pre', 'display': 'Yet to play'}   True   STK
# 779  {'status': 'pre', 'display': 'Yet to play'}   True   WCE
# 780  {'status': 'pre', 'display': 'Yet to play'}  False   FRE
#
#                                           player_stats  \
# 0    [{'player_id': 714, 'round': 0, 'points': 0, '...
# 1    [{'player_id': 643, 'round': 0, 'points': 0, '...
# 2    [{'player_id': 292, 'round': 0, 'points': 0, '...
# 3    [{'player_id': 463, 'round': 0, 'points': 0, '...
# 4    [{'player_id': 447, 'round': 0, 'points': 0, '...
# ..                                                 ...
# 776  [{'player_id': 778, 'round': 0, 'points': 0, '...
# 777  [{'player_id': 779, 'round': 0, 'points': 0, '...
# 778  [{'player_id': 780, 'round': 0, 'points': 0, '...
# 779  [{'player_id': 781, 'round': 0, 'points': 0, '...
# 780  [{'player_id': 254, 'round': 0, 'points': 0, '...
#
#                                              positions notes position  \
# 0    [{'position': 'MID', 'position_long': 'Midfiel...    []      MID
# 1    [{'position': 'MID', 'position_long': 'Midfiel...    []      MID
# 2    [{'position': 'MID', 'position_long': 'Midfiel...    []      MID
# 3    [{'position': 'MID', 'position_long': 'Midfiel...    []      MID
# 4    [{'position': 'RUC', 'position_long': 'Ruck', ...    []      RUC
# ..                                                 ...   ...      ...
# 776  [{'position': 'FWD', 'position_long': 'Forward...    []      FWD
# 777  [{'position': 'FWD', 'position_long': 'Forward...    []      FWD
# 778  [{'position': 'FWD', 'position_long': 'Forward...    []  FWD RUC
# 779  [{'position': 'FWD', 'position_long': 'Forward...    []  FWD RUC
# 780  [{'position': 'MID', 'position_long': 'Midfiel...    []      MID
#
#             long_team     adp
# 0    Western Bulldogs  2.7505
# 1            St Kilda  3.9824
# 2          Gold Coast  6.9938
# 3           Melbourne  5.1812
# 4           Melbourne  5.3938
# ..                ...     ...
# 776          Essendon     NaN
# 777          Essendon     NaN
# 778          St Kilda     NaN
# 779        West Coast     NaN
# 780         Fremantle     NaN
#
# [781 rows x 21 columns]

# %%
df_sc.to_csv('2022_SC_Player_list.csv')
