# %%
import pandas as pd
def flatten_position(column, requested_field):
    pos_list = []
    for pos in column:
        pos_list.append(pos[requested_field])
    return ' '.join(pos_list)


df_sc = pd.read_json('SC_2023_player_data_v2.json')
df_sc['position'] = df_sc['positions'].apply(lambda x: flatten_position(x, 'position'))
df_sc['long_team'] = df_sc['team'].apply(lambda x: x['name'])
df_sc['team'] = df_sc['team'].apply(lambda x: x['abbrev'])
df_sc['adp'] = df_sc['player_stats'].apply(lambda x: x[0]['adp'])
df_sc
# Out:
#       id first_name     last_name  team_id  previous_games  previous_average  \
# 0     18       Rory         Laird        1              20            127.85
# 1    463    Clayton        Oliver       10              21            127.10
# 2     77     Lachie         Neale        2              22            122.82
# 3    294       Touk        Miller       17              22            120.32
# 4    680     Callum         Mills       14              22            116.68
# ..   ...        ...           ...      ...             ...               ...
# 789  792     Kaelan       Bradtke       12               0              0.00
# 790  793        Kye        Turner       10               0              0.00
# 791  794       Alex      Cincotta        3               0              0.00
# 792  577      Jason  *** Castagna       12              16             51.19
# 793   20    Fischer    *** McAsey        1               0              0.00
#
#      previous_total  feed_id hs_url injury_suspension_status  ... locked  \
# 0              2557   293222                            None  ...  False
# 1              2669   996701                            None  ...  False
# 2              2702   293535                            None  ...  False
# 3              2647   298272                          Injury  ...  False
# 4              2567   993905                            None  ...  False
# ..              ...      ...    ...                      ...  ...    ...
# 789               0  1029288                            None  ...  False
# 790               0  1023274                            None  ...  False
# 791               0  1016268                            None  ...  False
# 792             819   991933                          Injury  ...  False
# 793               0  1009201                            None  ...  False
#
#                                    played_status  active team  \
# 0    {'status': 'pre', 'display': 'Yet to play'}    True  ADE
# 1    {'status': 'pre', 'display': 'Yet to play'}    True  MEL
# 2    {'status': 'pre', 'display': 'Yet to play'}    True  BRL
# 3    {'status': 'pre', 'display': 'Yet to play'}    True  GCS
# 4    {'status': 'pre', 'display': 'Yet to play'}    True  SYD
# ..                                           ...     ...  ...
# 789  {'status': 'pre', 'display': 'Yet to play'}    True  RIC
# 790  {'status': 'pre', 'display': 'Yet to play'}    True  MEL
# 791  {'status': 'pre', 'display': 'Yet to play'}    True  CAR
# 792  {'status': 'pre', 'display': 'Yet to play'}   False  RIC
# 793  {'status': 'pre', 'display': 'Yet to play'}   False  ADE
#
#                                           player_stats  \
# 0    [{'player_id': 18, 'round': 0, 'points': 0, 'p...
# 1    [{'player_id': 463, 'round': 0, 'points': 0, '...
# 2    [{'player_id': 77, 'round': 0, 'points': 0, 'p...
# 3    [{'player_id': 294, 'round': 0, 'points': 0, '...
# 4    [{'player_id': 680, 'round': 0, 'points': 0, '...
# ..                                                 ...
# 789  [{'player_id': 792, 'round': 0, 'points': 0, '...
# 790  [{'player_id': 793, 'round': 0, 'points': 0, '...
# 791  [{'player_id': 794, 'round': 0, 'points': 0, '...
# 792  [{'player_id': 577, 'round': 0, 'points': 0, '...
# 793  [{'player_id': 20, 'round': 0, 'points': 0, 'p...
#
#                                              positions notes position  \
# 0    [{'position': 'MID', 'position_long': 'Midfiel...    []      MID
# 1    [{'position': 'MID', 'position_long': 'Midfiel...    []      MID
# 2    [{'position': 'MID', 'position_long': 'Midfiel...    []      MID
# 3    [{'position': 'MID', 'position_long': 'Midfiel...    []      MID
# 4    [{'position': 'MID', 'position_long': 'Midfiel...    []      MID
# ..                                                 ...   ...      ...
# 789  [{'position': 'FWD', 'position_long': 'Forward...    []      FWD
# 790  [{'position': 'DEF', 'position_long': 'Defende...    []      DEF
# 791  [{'position': 'DEF', 'position_long': 'Defende...    []  DEF MID
# 792  [{'position': 'FWD', 'position_long': 'Forward...    []      FWD
# 793  [{'position': 'DEF', 'position_long': 'Defende...    []  DEF FWD
#
#       long_team       adp
# 0      Adelaide    3.5964
# 1     Melbourne    2.6094
# 2      Brisbane    4.5393
# 3    Gold Coast    6.4004
# 4        Sydney    8.6819
# ..          ...       ...
# 789    Richmond  177.8000
# 790   Melbourne  201.5000
# 791     Carlton  185.2000
# 792    Richmond       NaN
# 793    Adelaide       NaN
#
# [794 rows x 22 columns]

# %%
df_sc.to_csv('2023_SC_Player_list.csv')
