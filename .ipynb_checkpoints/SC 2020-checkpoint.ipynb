# %%
import pandas as pd

# %%
def flatten_position(column, requested_field):
    pos_list = []
    for pos in column:
        pos_list.append(pos[requested_field])
    return ' '.join(pos_list)


df_sc = pd.read_json('SC_2020_player_data.json')

df_sc['position'] = df_sc['positions'].apply(lambda x: flatten_position(x, 'position'))
df_sc['long_team'] = df_sc['team'].apply(lambda x: x['name'])
df_sc['team'] = df_sc['team'].apply(lambda x: x['abbrev'])
df_sc
# Out:
#       id first_name last_name  team_id   price  previous_games  \
# 0      1       Rory    Atkins        1  410000              20
# 1      2       Luke     Brown        1  369300              15
# 2      3     Jordon     Butts        1  123900               0
# 3      4        Ben   Crocker        1  152000               3
# 4      5       Brad    Crouch        1  534100              22
# ..   ...        ...       ...      ...     ...             ...
# 810  812       Jake  Waterman       16  301600              11
# 811  813    Francis    Watson       16  218300               2
# 812  814     Bailey  Williams       16  123900               0
# 813  815     Elliot       Yeo       16  584400              21
# 814  816       Jack    Newnes        3  386400              20
#
#      previous_average  previous_total  feed_id  active  \
# 0               75.50            1510   294472    True
# 1               68.00            1020   293193    True
# 2                0.00               0  1004995    True
# 3               35.00             105   993796    True
# 4               98.36            2164   294307    True
# ..                ...             ...      ...     ...
# 810             55.55             611   996554    True
# 811             67.00             134   298474    True
# 812              0.00               0  1006114    True
# 813            107.62            2260   292128    True
# 814             71.15            1423   291773    True
#
#                                              positions team position  \
# 0    [{'position': 'MID', 'position_long': 'Midfiel...  ADE      MID
# 1    [{'position': 'DEF', 'position_long': 'Defende...  ADE      DEF
# 2    [{'position': 'DEF', 'position_long': 'Defende...  ADE      DEF
# 3    [{'position': 'FWD', 'position_long': 'Forward...  ADE      FWD
# 4    [{'position': 'MID', 'position_long': 'Midfiel...  ADE      MID
# ..                                                 ...  ...      ...
# 810  [{'position': 'FWD', 'position_long': 'Forward...  WCE      FWD
# 811  [{'position': 'DEF', 'position_long': 'Defende...  WCE      DEF
# 812  [{'position': 'DEF', 'position_long': 'Defende...  WCE      DEF
# 813  [{'position': 'MID', 'position_long': 'Midfiel...  WCE      MID
# 814  [{'position': 'MID', 'position_long': 'Midfiel...  CAR      MID
#
#       long_team
# 0      Adelaide
# 1      Adelaide
# 2      Adelaide
# 3      Adelaide
# 4      Adelaide
# ..          ...
# 810  West Coast
# 811  West Coast
# 812  West Coast
# 813  West Coast
# 814     Carlton
#
# [815 rows x 14 columns]
